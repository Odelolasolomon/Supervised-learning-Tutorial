# %% [markdown]
# # Project: Predict  the likelihood of a new patient having heart disease in the future or not.
# <ul>
# <li><a href="#intro">Introduction</a></li>
# <li><a href="#wrangling">Data Wrangling</a></li>
# <li><a href="#eda">Exploratory Data Analysis</a></li>
# <li><a href="#conclusions">Conclusions</a></li>
# </ul>

# %% [markdown]
# <a id='intro'></a>
#
# ## Introduction
#
#
#
# The World Health Organization (WHO) estimates that 17.9 million people die from cardiovascular diseases (CVDs) every year.
#
# There are multiple risk factors that could contribute to CVD in an individual, such as unhealthy diet, lack of physical activity, or mental illness. Identifying these risk factors early on could help prevent many premature deaths.
#
# We are working for an R&D company that focuses on providing healthcare solutions. The company has collected anonymized data from multiple hospitals on several patients. The dataset includes relevant information for each patient, such as their personal information and some medical data, including whether or not they have had heart disease before.
# We are tasked with using the dataset to accurately predict the likelihood of a new patient having heart disease in the future. The dataset has the following features:
# - Age: age of the patient [years]
# - Sex: sex of the patient [M: Male, F: Female]
# - ChestPainType: chest pain type [TA: Typical Angina, ATA: Atypical Angina, NAP: Non-Anginal Pain, ASY: Asymptomatic]
# - RestingBP: resting blood pressure [mm Hg]
# - Cholesterol: serum cholesterol [mm/dl]
# - FastingBS: fasting blood sugar [1: if FastingBS > 120 mg/dl, 0: otherwise]
# - RestingECG: resting electrocardiogram results [Normal: Normal, ST: having ST-T wave abnormality (T wave inversions and/or ST elevation or depression of > 0.05 mV), LVH: showing probable or definite left ventricular hypertrophy by Estes' criteria]
# - MaxHR: maximum heart rate achieved [Numeric value between 60 and 202]
# - ExerciseAngina: exercise-induced angina [Y: Yes, N: No]
# - Oldpeak: oldpeak = ST [Numeric value measured in depression]
# - ST_Slope: the slope of the peak exercise ST segment [Up: upsloping, Flat: flat, Down: downsloping]
# - HeartDisease: output class [1: heart disease, 0: Normal]
# Before we jump into building a model, i will conduct exploratory data analysis on the dataset
#
# Please note: For each step of the project, i am encouraged to add appropriate headers or subheaders and any discussions or explanations i see fit.

# %% [markdown]
# <a id='wrangling'></a>
# ## Data Wrangling

# %% [markdown]
# ### Assess

# %%
#import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
health= pd.read_csv('heart_disease_prediction.csv')

# %%
health.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
#display the programmatic info of the data
health.info
# Out:
# <bound method DataFrame.info of      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
#dimension of the dat
health.shape
# Out:
# (918, 12)

# %%
health.isnull().sum()
# Out:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64

# %%
#check if there are duplicates
health.duplicated().sum()
# Out:
# 0

# %%
#display the data types
health.dtypes
# Out:
# Age                 int64
# Sex                object
# ChestPainType      object
# RestingBP           int64
# Cholesterol         int64
# FastingBS           int64
# RestingECG         object
# MaxHR               int64
# ExerciseAngina     object
# Oldpeak           float64
# ST_Slope           object
# HeartDisease        int64
# dtype: object

# %%
#show each columns
health.columns
# Out:
# Index(['Age', 'Sex', 'ChestPainType', 'RestingBP', 'Cholesterol', 'FastingBS',
#        'RestingECG', 'MaxHR', 'ExerciseAngina', 'Oldpeak', 'ST_Slope',
#        'HeartDisease'],
#       dtype='object')

# %%
#display the summary statistics of the numerical variables
health.describe()
# Out:
#               Age   RestingBP  Cholesterol   FastingBS       MaxHR  \
# count  918.000000  918.000000   918.000000  918.000000  918.000000
# mean    53.510893  132.396514   198.799564    0.233115  136.809368
# std      9.432617   18.514154   109.384145    0.423046   25.460334
# min     28.000000    0.000000     0.000000    0.000000   60.000000
# 25%     47.000000  120.000000   173.250000    0.000000  120.000000
# 50%     54.000000  130.000000   223.000000    0.000000  138.000000
# 75%     60.000000  140.000000   267.000000    0.000000  156.000000
# max     77.000000  200.000000   603.000000    1.000000  202.000000
#
#           Oldpeak  HeartDisease
# count  918.000000    918.000000
# mean     0.887364      0.553377
# std      1.066570      0.497414
# min     -2.600000      0.000000
# 25%      0.000000      0.000000
# 50%      0.600000      1.000000
# 75%      1.500000      1.000000
# max      6.200000      1.000000

# %%
health['Sex'].value_counts()
# Out:
# M    725
# F    193
# Name: Sex, dtype: int64

# %%
health['ChestPainType'].value_counts()
# Out:
# ASY    496
# NAP    203
# ATA    173
# TA      46
# Name: ChestPainType, dtype: int64

# %%
health['RestingECG'].value_counts()
# Out:
# Normal    552
# LVH       188
# ST        178
# Name: RestingECG, dtype: int64

# %%
health['ExerciseAngina'].value_counts()
# Out:
# N    547
# Y    371
# Name: ExerciseAngina, dtype: int64

# %%
health['ST_Slope'].value_counts()
# Out:
# Flat    460
# Up      395
# Down     63
# Name: ST_Slope, dtype: int64

# %%
sns.boxplot(data=health, x='Cholesterol')
plt.xlabel('Patients Cholesterol')
plt.title('Distribution of Patients Cholesterol');

# %%
sns.boxplot(data=health, x='Oldpeak')
plt.xlabel('Patients Oldpeak')
plt.title('Distribution of Patients Oldpeak');

# %%
health['HeartDisease']=health['HeartDisease'].astype('category')

# %%
health.dtypes
# Out:
# Age                  int64
# Sex                 object
# ChestPainType       object
# RestingBP            int64
# Cholesterol          int64
# FastingBS            int64
# RestingECG          object
# MaxHR                int64
# ExerciseAngina      object
# Oldpeak            float64
# ST_Slope            object
# HeartDisease      category
# dtype: object

# %% [markdown]
# <a id='eda'></a>
# ## Exploratory Data Analysis

# %% [markdown]
# ### Univariate Analysis

# %% [markdown]
# ### Question1(What is the Distribution of Patients Ages?)

# %%
health.describe()
# Out:
#               Age   RestingBP  Cholesterol   FastingBS       MaxHR     Oldpeak
# count  918.000000  918.000000   918.000000  918.000000  918.000000  918.000000
# mean    53.510893  132.396514   198.799564    0.233115  136.809368    0.887364
# std      9.432617   18.514154   109.384145    0.423046   25.460334    1.066570
# min     28.000000    0.000000     0.000000    0.000000   60.000000   -2.600000
# 25%     47.000000  120.000000   173.250000    0.000000  120.000000    0.000000
# 50%     54.000000  130.000000   223.000000    0.000000  138.000000    0.600000
# 75%     60.000000  140.000000   267.000000    0.000000  156.000000    1.500000
# max     77.000000  200.000000   603.000000    1.000000  202.000000    6.200000

# %%
health[['Age','MaxHR']].describe()
# Out:
#               Age       MaxHR
# count  918.000000  918.000000
# mean    53.510893  136.809368
# std      9.432617   25.460334
# min     28.000000   60.000000
# 25%     47.000000  120.000000
# 50%     54.000000  138.000000
# 75%     60.000000  156.000000
# max     77.000000  202.000000

# %%
plt.figure(figsize=[8,5])

base_color=sns.color_palette()[0]
bin_size=np.arange(20, health['Age'].max(),2)
binsize=np.arange(50, health['MaxHR'].max(), 5)

plt.subplot(1,2,1)
sns.histplot(data=health, x='MaxHR', bins=binsize, color=base_color, kde=True)
plt.title('Distribution of MaxHR')
plt.xlabel('MaxHR')
plt.ylabel('Count of MaxHR');


plt.subplot(1,2,2)
sns.histplot(data=health, x='Age', bins=bin_size, color=base_color, kde=True)
plt.title('Distribution of Patients Ages')
plt.xlabel('Patients Ages')
plt.ylabel('Count of Patients Ages');

# %% [markdown]
#  ### Question 2( What is the distribution of Patients Cholesterol?)

# %%
health['Cholesterol'].describe()
# Out:
# count    918.000000
# mean     198.799564
# std      109.384145
# min        0.000000
# 25%      173.250000
# 50%      223.000000
# 75%      267.000000
# max      603.000000
# Name: Cholesterol, dtype: float64

# %%
plt.figure(figsize=[8,5])

plt.subplot(1,2,1)
binsize=np.arange(0, health['Cholesterol'].max(), 20)
base_color=sns.color_palette()[4]
sns.histplot(data=health, x='Cholesterol', kde=True, bins=binsize, color=base_color)
plt.title('Distribution of Patients Cholesterol')

plt.subplot(1,2,2)
sns.boxplot(data=health, x='Cholesterol')
plt.title('Distribution Of Cholesterol');

# %% [markdown]
# ### Question 3(Which Type of Chest Pain is More Common among Patients?)

# %%
sns.countplot(data=health, x='ChestPainType', color=sns.color_palette()[2])
plt.xlabel('Chest Pain Type')
plt.title('Count of Chest Pain Type');

# %% [markdown]
# ### Question 4(What is the Distribution of Patient's Maximum HR and Old Peak?)

# %%
health[['MaxHR','Oldpeak']].describe()
# Out:
#             MaxHR     Oldpeak
# count  918.000000  918.000000
# mean   136.809368    0.887364
# std     25.460334    1.066570
# min     60.000000   -2.600000
# 25%    120.000000    0.000000
# 50%    138.000000    0.600000
# 75%    156.000000    1.500000
# max    202.000000    6.200000

# %%
plt.figure(figsize=[9,5])
#MaxHR	Oldpeak

binsize1=np.arange(50, health['MaxHR'].max(), 10)
plt.subplot(1,2,1)
sns.histplot(data=health, x='MaxHR', color=sns.color_palette()[0], kde=True, bins=binsize1)
plt.title('Distribution of Patients MaxHR')

binsize2=np.arange(0, health['Oldpeak'].max(), 0.6)
plt.subplot(1,2,2)
sns.histplot(data=health, x='Oldpeak', color=sns.color_palette()[0], kde=True, bins=binsize2)
plt.title('Distribution of Patients Old Peak');

# %% [markdown]
# ### Bivariate Analysis

# %% [markdown]
# ### Question5( What is the Relationship between Patient's Chest Pain Type and Heart Disease and Resting ECG?)

# %%
plt.figure(figsize=[10,5])

plt.subplot(1,2,1)
sns.violinplot(data=health, x='ChestPainType', y='Cholesterol')

plt.subplot(1,2,2)
sns.boxplot(data=health, x='RestingECG', y='Cholesterol');
# Out:
# <AxesSubplot:xlabel='RestingECG', ylabel='Cholesterol'>

# %% [markdown]
# ### Multivariate Analysis
